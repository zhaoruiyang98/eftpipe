# %%
# Show plots inline, and load main getdist plot module and samples class
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, MCSamples
import getdist
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# matplotlib 2 may not work very well without usetex on, can uncomment
# plt.rcParams['text.usetex']=True
# Out:
# GetDist Version: 1.3.4, Matplotlib version: 3.5.1

# %%
# %matplotlib notebook
# Get some random samples for demonstration:
# make random covariance, then independent samples from Gaussian
import numpy as np
ndim = 4
nsamp = 10000
random_state = np.random.default_rng(10) # seed random generator
A = random_state.random((ndim,ndim))
cov = np.dot(A, A.T)
samps = random_state.multivariate_normal([0]*ndim, cov, size=nsamp)
A = random_state.random((ndim,ndim))
cov = np.dot(A, A.T)
samps2 = random_state.multivariate_normal([0]*ndim, cov, size=nsamp)

# %%
# Get the getdist MCSamples objects for the samples, specifying same parameter
# names and labels; if not specified weights are assumed to all be unity
names = ["x%s"%i for i in range(ndim)]
labels =  ["x_%s"%i for i in range(ndim)]
samples = MCSamples(samples=samps,names = names, labels = labels)
samples2 = MCSamples(samples=samps2,names = names, labels = labels, label='Second set')
# Out:
# Removed no burn in
# Removed no burn in

# %%
# Triangle plot
g = plots.get_subplot_plotter()
g.triangle_plot([samples, samples2], filled=True)

# %%
# Export the results to GetDist
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gd_sample = loadMCSamples(
    'yamls/chains/gaussian',
    settings={'ignore_rows': 0.1}
)#MCSamplesFromCobaya(info, data.products()["sample"])
# Analyze and plot
mean = gd_sample.getMeans()[:2]
covmat = gd_sample.getCovMat().matrix[:2, :2]
print("Mean:")
print(mean)
print("Covariance matrix:")
print(covmat)
# %matplotlib inline  # uncomment if running from the Jupyter notebook
import getdist.plots as gdplt

gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(gd_sample, ["a", "b"], filled=True)
# Out:
# WARNING:root:outlier fraction 0.038011695906432746
# yamls/chains/gaussian.1.txt
# Removed 0.1 as burn in
# Mean:
# [ 0.20115859 -0.01146482]
# Covariance matrix:
# [[0.09216085 0.03711602]
#  [0.03711602 0.17192564]]

# %%
# %matplotlib inline
import getdist.plots as gdplt
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gdsamples = loadMCSamples(
    'yamls/chains/ring',
    settings={'ignore_rows': 0.1})

gdplot = gdplt.get_subplot_plotter(width_inch=5)
gdplot.triangle_plot(gdsamples, ["x", "y"], filled=True)
gdplot = gdplt.get_subplot_plotter(width_inch=5)
gdplot.plots_1d(gdsamples, ["r", "theta"], nx=2)
# Out:
# yamls/chains/ring.1.txt
# Removed 0.1 as burn in
# (2, 1)

# %%
# %matplotlib inline
import getdist.plots as gdplt
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gdsamples = loadMCSamples(
    'yamls/chains/ring',
    settings={'ignore_rows': 0.1})

gdplot = gdplt.get_subplot_plotter(width_inch=5)
gdplot.triangle_plot(gdsamples, ["r", "theta"], filled=True)

# %%
# %matplotlib inline
import getdist.plots as gdplt
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gdsamples = loadMCSamples(
    '/home/dell/Templates/eftpipe/cobaya/chains/4xmock_LRG_NGC_km0p15_marg',
    settings={'ignore_rows': 0.1})

gdplot = gdplt.get_subplot_plotter(width_inch=10)
gdplot.triangle_plot(gdsamples,['omegam','H0', 'sigma8','LRG_NGC_b1','LRG_NGC_c2'], markers={'omegam':0.3106, 'H0': 67.91, 'sigma8': 0.83},filled=True,title_limit=1)
# Out:
# /home/dell/Templates/eftpipe/cobaya/chains/4xmock_LRG_NGC_km0p15_marg.1.txt
# Removed 0.1 as burn in

# %%
# %matplotlib inline
import getdist.plots as gdplt
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gdsamples = loadMCSamples(
    '/home/dell/Templates/eftpipe/cobaya/chains/mock_LRG_ELG_x_NGC_km0p15_marg',
    settings={'ignore_rows': 0.1})

gdplot = gdplt.get_subplot_plotter(width_inch=10)
gdplot.triangle_plot(gdsamples,['omegam','H0', 'sigma8'], markers={'omegam':0.3106, 'H0': 67.91, 'sigma8': 0.83},filled=True,title_limit=1)

# %%
# %matplotlib inline
import getdist.plots as gdplt
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gdsamples = loadMCSamples(
    '/home/dell/Templates/eftpipe/cobaya/chains/mock_x_NGC_km0p15_marg',
    settings={'ignore_rows': 0.1})

gdplot = gdplt.get_subplot_plotter(width_inch=10)
gdplot.triangle_plot(gdsamples,['omegam','H0', 'sigma8'], markers={'omegam':0.3106, 'H0': 67.91, 'sigma8': 0.83},filled=True,title_limit=1)

# %%
# %matplotlib inline
import getdist.plots as gdplt
from getdist.mcsamples import MCSamplesFromCobaya, loadMCSamples


gdsamples = loadMCSamples(
    '/home/dell/Templates/eftpipe/cobaya/chains/remock_x_NGC_km0p15_marg',
    settings={'ignore_rows': 0.1})

gdplot = gdplt.get_subplot_plotter(width_inch=10)
gdplot.triangle_plot(gdsamples,['omegam','H0', 'sigma8'],markers={'omegam':0.3106, 'H0': 67.91, 'sigma8': 0.83}, filled=True,title_limit=1)
# Out:
# /home/dell/Templates/eftpipe/cobaya/chains/remock_x_NGC_km0p15_marg.1.txt
# Removed 0.1 as burn in
